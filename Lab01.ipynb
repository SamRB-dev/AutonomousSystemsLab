# %% [markdown]
# <a href="https://colab.research.google.com/github/SamRB-dev/AutonomousSystemsLab/blob/main/Lab01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook 0: Jupyter Basics
#
# ## Learning objectives
# After working through this notebook, you should be able to:
# - distinguish between markdown cells and code cells,
# - execute cells in the correct order,
# - use simple Python variables,
# - edit notebook content and observe changed output.
#
# ## Why this notebook?
# Before working with machine learning, you need to feel comfortable with the working environment.
# Jupyter Notebook is an interactive environment in which you can combine:
# - executable Python code,
# - explanatory text,
# - equations, plots, and observations.
#
# ## References
# 1. Project Jupyter, Documentation.
# 2. Jake VanderPlas, Python Data Science Handbook, O'Reilly, Chapter 1.

# %% [markdown]
# ## Part 1: Markdown cells and code cells
#
# A **markdown cell** contains text.
# A **code cell** contains Python code and can be executed.
#
# Run the next cell.

# %%
print("This is a string")
# Out:
# This is a string

# %% [markdown]
# ### Task 0.1
# Change the text inside the `print(...)` command and run the cell again.
#
# ### Reflection
# - What changed?
# - Did you modify the code or only the output?

# %% [markdown]
# ## Part 2: Simple calculations
#
# A notebook can also be used like a calculator.
# Run the next cells and observe the outputs.

# %%
3 + 5
# Out:
# 8

# %%
3 * 8 + 2
# Out:
# 26

# %%
10 - 3
# Out:
# 7

# %%
5 * 6
# Out:
# 30

# %%
12 / 4
# Out:
# 3.0

# %% [markdown]
# ### Task 0.2
# Create a new code cell below and compute:
# - `10 - 3`
# - `5 * 6`
# - `12 / 4`
#
# ### Reflection
# Why is it useful to test small calculations interactively?

# %% [markdown]
# ## Part 3: Variables
#
# A **variable** stores a value.
# In Python, you can assign a value using `=`.

# %%
x = 7
print(x)
# Out:
# 7

# %%
message = "Autonomous Systems Lab"
print(message)
# Out:
# Autonomous Systems Lab

# %%
a: int = 1230011
course_name: str = "Autonomous Systems A (ASA)"
print(f"{a}\n{course_name}")
# Out:
# 1230011
# Autonomous Systems A (ASA)

# %% [markdown]
# ### Task 0.3
# Create two variables:
# - one integer variable called `a`,
# - one text variable called `course_name`.
#
# Print both variables.

# %% [markdown]
# ## Part 4: Re-running cells
#
# The notebook does not only show code. It also stores the current program state in memory.
# This state is managed by the **kernel**.
#
# Run the following cell.

# %%
counter = 1
print(counter)
# Out:
# 1

# %%
counter += 1
print(counter)
# Out:
# 5

# %% [markdown]
# Now change the code to:
# ```python
# counter = counter + 1
# print(counter)
# ```
# Run it several times.
#
# ### Reflection
# - Why does the result change each time?
# - What does this tell you about the notebook kernel?

# %% [markdown]
# ## Part 5: Short summary
#
# You have now used:
# - markdown cells,
# - code cells,
# - variables,
# - repeated execution.
#
# These are the basic tools needed for the following notebooks.
#
# ## Final mini-task
# Create a new code cell and do the following:
# 1. store your name in a variable,
# 2. store the current semester in another variable,
# 3. print both values in one output.

# %%
studentName: str = "Sadim Rahman Badhan"
studentSemester: int = 6
print(f"Name: {studentName} Semester: {studentSemester}")
# Out:
# Name: Sadim Rahman Badhan Semester: 6

# %% [markdown]
# ## Suggested reading
# - Project Jupyter documentation
# - VanderPlas: *Python Data Science Handbook*, introduction and notebook basics
